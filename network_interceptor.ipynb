# %% [markdown]
# # Network Interceptor (One‑Click)
#
# **Run the cell below.** A green dot will appear. All `fetch` and `XMLHttpRequest` calls will be logged to your Oast server.
# A test request will be sent automatically to `httpbin.org` – check for `/FETCH` in your Oast logs.

# %%
# Run this cell – JavaScript will auto‑execute
print('Injecting network interceptor...')
# Out:
# Interceptor deployed. Look for green dot at bottom‑right.
