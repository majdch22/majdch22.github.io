# %% [markdown]
# # PoC10 — openUrl click bypass + li() URL sanitizer probe
# Tests openUrl() from a native click event. Gate: a.host.isTrusted() OR window.event.isTrusted.
# Tests https, javascript:, and data: URLs to map li() sanitizer behavior.

# %%
print('PoC10 running — click the button that appears below')
