# %% [markdown]
# # PoC12 — Widgets + eval chain + storage + parent nav
# Tests:
# 1. `window.google.colab.widgets` namespace
# 2. Proper async gate tests (invoke/comms/genVar)
# 3. BroadcastChannel `colab_comms_broadcast_channel`
# 4. `window.parent.location` write
# 5. localStorage/sessionStorage
# 6. auto `window.open` test
# 7. **Click 'Run Eval Chain' button** → blob URL → outputframe.html eval → same-origin access to this frame

# %%
print('PoC12 — click the red button in the output below')
