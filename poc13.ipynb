# %% [markdown]
# # PoC13 — blank popup navigation + installCustomManager + widget state probe
# 1. Uses auto-exec popup to test parent navigation from non-sandboxed context
# 2. Tests if installCustomManager fetches the URL (requirejs script tag)
# 3. Tries to render a fake widget to trigger get_widget_model_state
# 4. Eval chain via outputframe.html from popup

# %%
print('PoC13 running')
