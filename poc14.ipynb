# %% [markdown]
# # PoC14 — Custom Widget Manager via saved output (zero-click external JS load)
# When this notebook is opened:
# 1. Colab processes the saved widget output in cell 1
# 2. `Z.prototype.U` installs our custom manager from the `data:` URL
# 3. `import(data_url)` loads our ES module
# 4. Module logs to Caido: `/__poc14/MODULE_LOADED`
# 5. `al.prototype.U` calls ungated `host.request(get_widget_model_state)`
# 6. `commChannelOpened` fires if victim uses ipywidgets

# %%
# Cell that produced the saved widget output below
import ipywidgets as widgets
w = widgets.IntSlider(value=7, min=0, max=10)
display(w)
# Out:
# A Jupyter Widget

# %%
print('PoC14 JS baseline')
