# %% [markdown]
# # PoC15 — JS-first interception + blob:URL module load
# Output order: JS (interceptor) → widget_A → widget_B
# Key questions:
# 1. Does installCustomManager get called for saved widget outputs? (ICM_INTERCEPTED)
# 2. Does import() succeed for data: URLs? (DIRECT_DATA_A/B_LOADED vs ERR)
# 3. Does blob: URL import work? (INLINE_BLOB_A_LOADED vs ERR)
# 4. Which export pattern (named/default) does Colab expect? (ICM_RESOLVED keys)
# 5. Does blob: URL path trigger createWidgetManager? (MOD_A/B_CWM_CALLED)

# %%
# JS-first then widgets in same cell
# Out:
# A Jupyter Widget (named)
# A Jupyter Widget (default)
