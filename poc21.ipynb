# %% [markdown]
# # poc21 — page-wide manager test
# Cell 1: zero-click autoexec installs manager (no kernel needed)
# Cell 2: clean widget cell, no install code
# Question: does CWM_CALLED fire when Cell 2 runs?

# %%
# autoexec

# %%
import ipywidgets as widgets
from IPython.display import display

# Clean widget cell - no install code here
# If Caido shows CWM_CALLED -> manager from Cell 1 autoexec is PAGE-WIDE
display(widgets.Password(description='API Key:', value='sk-proj-TEST-SECRET'))
display(widgets.Dropdown(options=['prod','staging'], value='prod', description='Env:'))
