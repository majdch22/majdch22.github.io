# %% [markdown]
# # poc67 — OAuth redirect chain + LSID service reach + JWT API probe
#
# Tests: OAuth img redirect behavior, full service reach from LSID, whether proxyPort JWT authenticates to Colab REST API.

# %%
# poc67: frame JWT probe

# %% [markdown]
# <img src="https://accounts.google.com/o/oauth2/auth?response_type=code&scope=email+profile&redirect_uri=https://colab.research.google.com/__poc67/OAUTH_REDIRECT_CB&prompt=none&client_id=1" width="1" height="1">
#
# OAuth probe: does img load follow redirect? Watch for OAUTH_REDIRECT_CB in Caido with any code/error params.

# %% [markdown]
# <img src="https://accounts.google.com/o/oauth2/auth?response_type=code&scope=email&redirect_uri=https://colab.research.google.com/__poc67/OAUTH_ERROR_REDIRECT&client_id=407408718192.apps.googleusercontent.com" width="1" height="1">
#
# Real client_id OAuth probe — redirect_uri mismatch expected, but error= should come as a redirect to our URL if img follows oauth redirects.

# %% [markdown]
# <img src="https://shell.cloud.google.com/__poc67/CLOUDSHELL_REACH" width="1" height="1">
#
# Cloud Shell reach test — LSID includes o.shell.cloud.google.com, confirms auth cookies sent to cloud shell domain.

# %% [markdown]
# <img src="https://console.cloud.google.com/__poc67/GCP_CONSOLE_REACH" width="1" height="1">
#
# GCP console reach test — LSID includes o.console.cloud.google.com.

# %% [markdown]
# <img src="https://mail.google.com/__poc67/GMAIL_REACH" width="1" height="1">
#
# Gmail reach test — LSID includes o.mail.google.com.

# %% [markdown]
# <img src="https://myaccount.google.com/__poc67/MYACCOUNT_REACH" width="1" height="1">
#
# myaccount reach test — LSID includes o.myaccount.google.com.
