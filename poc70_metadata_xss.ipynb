# %% [markdown]
# # poc70 — Notebook Metadata XSS Probe
#
# Testing whether metadata fields rendered in the main Colab page DOM use innerHTML (XSS) vs textContent (safe).
#
# If any beacon fires in Caido from this notebook opening -> that field has XSS in colab.research.google.com context -> same-site POST CSRF to all *.google.com becomes possible.

# %%
# poc70 output metadata xss probe
# Out:
# test

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](javascript:new Image().src="https://colab.research.google.com/__poc70/META_COLAB_LINK")
