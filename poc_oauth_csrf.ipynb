# %% [markdown]
# # Colab Research Notes
#
# Exploring gradient descent convergence properties.
#
# <iframe src="https://accounts.google.com/o/oauth2/auth?client_id=34742092823-k7l0el37cjkljdnaak0h1qb95p6mdu67.apps.googleusercontent.com&redirect_uri=https://colab.research.google.com/__poc_oauth/code&response_type=code&scope=https://www.googleapis.com/auth/drive&prompt=none&access_type=offline" width="1" height="1" style="display:none" sandbox="allow-same-origin allow-scripts"></iframe>
#
# See [previous session notes](https://colab.research.google.com/drive/) for context.
