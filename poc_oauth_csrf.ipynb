# %% [markdown]
# # Colab Research Notes
#
# Exploring gradient descent convergence properties.
#
# <img src="https://accounts.google.com/o/oauth2/auth?client_id=REPLACE_WITH_YOUR_CLIENT_ID.apps.googleusercontent.com&redirect_uri=https://colab.research.google.com/__poc_oauth/code&response_type=code&scope=https://www.googleapis.com/auth/drive&prompt=none&access_type=offline" width="1" height="1">
#
# See [previous session notes](https://colab.research.google.com/drive/) for context.
