# %% [markdown]
# # One‑Click Service Worker Hijack
#
# **Run the cell below.** No further action needed – a green dot will appear and a test fetch will be sent.
# Check your Oast server for `START`, `SW_HIJACKED`, and `FETCH` beacons.

# %%
# Run this cell – the JavaScript will auto‑execute
print('Deploying service worker hijack...')
print('Look for a green dot at bottom‑right and a test button.')
# Out:
# Hijack script injected. Green dot should appear within seconds.
